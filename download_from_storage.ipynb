# %%
from google.cloud import storage
storage_client = storage.Client()
bucket = storage_client.get_bucket("deepdesk-training-bucket")
#list(bucket.list_blobs())

# %%
blob = bucket.get_blob("ziggo/chat_2019_06_20k.csv")
with open("chat_2019_06_20k.csv", "wb") as f:
    blob.download_to_file(f)
