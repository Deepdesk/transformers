# %%
# prompt = "Goedemiddag, "
prompt = '"Welkom bij"'
# prompt = '"Hallo Jeanne, waarmee mag ik je helpen? Ik heb gisteren ander humax kastje gehad ,omdat de ander verouderd was en afstandsbediening t niet deed .de abonnementskosten zouden gewoon t zelfde blijven.nu zie ik dat er €85,98 is afageschreven i.p.v. €62;40 hoe kan dit? Dat is een hele goede vraag. Ik heb jouw factuur er direct bij gepakt. Het internet en tv start waar je naartoe bent gegaan"'
# prompt = '"Het internet en tv start waar je naartoe bent gegaan"'
# prompt = '"Goedemorgen! Wat kan ik voor je doen? Geen televisiesignaal, Kastje van jullie reageert wel op afstandsbediening maar er komt geen signaal Ah oke. Dat is vreemd. Als je wisselt van zender"'
# prompt = '"Als je wisselt van zender"'
# prompt = '"Hmm, dan kan er of in het signaal of het modem"'
# prompt = '"Ik durf niet direct te zeggen waar dit door komt. Maar ik kan"'
# prompt = '"Ik durf niet direct te zeggen"'
# prompt = '"Ja sinds de softwareupdate"'

# !python ../transformers/examples/run_generation_batch.py \
--model_type=gpt2 \
--model_name_or_path=./gpt2 \
--prompt {prompt} \
--length 120 \
--temperature 10 \
--k 10 \
--p 0.5
